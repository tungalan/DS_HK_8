# %%
# %matplotlib inline
import pandas as pd
import os.path as path
import urllib2
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from pylab import rcParams
rcParams['figure.figsize'] = 10, 6

# Set some Pandas options
pd.set_option('max_columns', 30)
pd.set_option('max_rows', 20)

# Store data in a consistent place
DATA_FILE = '../../data/2008.csv.bz2'
URL = 'http://stat-computing.org/dataexpo/2009/2008.csv.bz2'

def download_if_needed(filename, url):
    if path.isfile(filename) is False:
        req = urllib2.urlopen(url)
        CHUNK_SIZE = 16 * 1024
        with open(filename, 'wb') as fp:
            while True:
                chunk = req.read(CHUNK_SIZE)
                if not chunk: break
                fp.write(chunk)

# %%
download_if_needed(DATA_FILE, URL)
df_flights = pd.read_csv(DATA_FILE, nrows = 100000, compression='bz2')
df_flights.head(10)
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  2008      1           3          4     2003        1955     2211
# 1  2008      1           3          4      754         735     1002
# 2  2008      1           3          4      628         620      804
# 3  2008      1           3          4      926         930     1054
# 4  2008      1           3          4     1829        1755     1959
# 5  2008      1           3          4     1940        1915     2121
# 6  2008      1           3          4     1937        1830     2037
# 7  2008      1           3          4     1039        1040     1132
# 8  2008      1           3          4      617         615      652
# 9  2008      1           3          4     1620        1620     1639
#
#    CRSArrTime UniqueCarrier  FlightNum TailNum  ActualElapsedTime  \
# 0        2225            WN        335  N712SW                128
# 1        1000            WN       3231  N772SW                128
# 2         750            WN        448  N428WN                 96
# 3        1100            WN       1746  N612SW                 88
# 4        1925            WN       3920  N464WN                 90
# 5        2110            WN        378  N726SW                101
# 6        1940            WN        509  N763SW                240
# 7        1150            WN        535  N428WN                233
# 8         650            WN         11  N689SW                 95
# 9        1655            WN        810  N648SW                 79
#
#    CRSElapsedTime  AirTime  ArrDelay  DepDelay Origin Dest  Distance  TaxiIn  \
# 0             150      116       -14         8    IAD  TPA       810       4
# 1             145      113         2        19    IAD  TPA       810       5
# 2              90       76        14         8    IND  BWI       515       3
# 3              90       78        -6        -4    IND  BWI       515       3
# 4              90       77        34        34    IND  BWI       515       3
# 5             115       87        11        25    IND  JAX       688       4
# 6             250      230        57        67    IND  LAS      1591       3
# 7             250      219       -18        -1    IND  LAS      1591       7
# 8              95       70         2         2    IND  MCI       451       6
# 9              95       70       -16         0    IND  MCI       451       3
#
#    TaxiOut  Cancelled CancellationCode  Diverted  CarrierDelay  WeatherDelay  \
# 0        8          0              NaN         0           NaN           NaN
# 1       10          0              NaN         0           NaN           NaN
# 2       17          0              NaN         0           NaN           NaN
# 3        7          0              NaN         0           NaN           NaN
# 4       10          0              NaN         0             2             0
# 5       10          0              NaN         0           NaN           NaN
# 6        7          0              NaN         0            10             0
# 7        7          0              NaN         0           NaN           NaN
# 8       19          0              NaN         0           NaN           NaN
# 9        6          0              NaN         0           NaN           NaN
#
#    NASDelay  SecurityDelay  LateAircraftDelay
# 0       NaN            NaN                NaN
# 1       NaN            NaN                NaN
# 2       NaN            NaN                NaN
# 3       NaN            NaN                NaN
# 4         0              0                 32
# 5       NaN            NaN                NaN
# 6         0              0                 47
# 7       NaN            NaN                NaN
# 8       NaN            NaN                NaN
# 9       NaN            NaN                NaN

# %%
df_flights.describe()
# Out:
#          Year   Month     DayofMonth      DayOfWeek       DepTime  \
# count  100000  100000  100000.000000  100000.000000  98858.000000
# mean     2008       1      17.087860       3.890040   1355.200722
# std         0       0       8.356364       1.952999    464.089632
# min      2008       1       1.000000       1.000000      1.000000
# 25%      2008       1      10.000000       2.000000    942.000000
# 50%      2008       1      17.000000       4.000000   1344.000000
# 75%      2008       1      24.000000       5.000000   1743.000000
# max      2008       1      31.000000       7.000000   2359.000000
#
#           CRSDepTime       ArrTime     CRSArrTime      FlightNum  \
# count  100000.000000  98698.000000  100000.000000  100000.000000
# mean     1341.989400   1492.739225    1502.601540    1510.648540
# std       451.356984    496.376794     478.100216    1186.128598
# min       600.000000      1.000000       5.000000       1.000000
# 25%       940.000000   1114.000000    1120.000000     502.000000
# 50%      1335.000000   1518.000000    1520.000000    1320.000000
# 75%      1730.000000   1913.000000    1910.000000    2362.000000
# max      2235.000000   2400.000000    2355.000000    7676.000000
#
#        ActualElapsedTime  CRSElapsedTime       AirTime      ArrDelay  \
# count       98698.000000   100000.000000  98698.000000  98698.000000
# mean          107.558502      111.989540     91.863797      5.729954
# std            55.350971       57.209135     54.208224     30.966959
# min            25.000000       17.000000     12.000000    -57.000000
# 25%            68.000000       70.000000     53.000000     -9.000000
# 50%            88.000000       90.000000     71.000000     -2.000000
# 75%           135.000000      145.000000    119.000000     10.000000
# max           382.000000      370.000000    369.000000    500.000000
#
#            DepDelay       Distance        TaxiIn       TaxiOut      Cancelled  \
# count  98858.000000  100000.000000  98698.000000  98858.000000  100000.000000
# mean      10.379049     630.586320      4.768962     10.927765       0.011420
# std       28.384428     437.357075      2.983635      5.989580       0.106253
# min      -44.000000      66.000000      1.000000      1.000000       0.000000
# 25%       -2.000000     324.000000      3.000000      8.000000       0.000000
# 50%        1.000000     453.000000      4.000000      9.000000       0.000000
# 75%       10.000000     843.000000      5.000000     12.000000       0.000000
# max      516.000000    2363.000000    213.000000    150.000000       1.000000
#
#             Diverted  CarrierDelay  WeatherDelay      NASDelay  SecurityDelay  \
# count  100000.000000  19629.000000  19629.000000  19629.000000   19629.000000
# mean        0.001600      9.573488      2.036120      8.353151       0.110805
# std         0.039968     21.836836     13.815868     18.826087       1.724888
# min         0.000000      0.000000      0.000000      0.000000       0.000000
# 25%         0.000000      0.000000      0.000000      0.000000       0.000000
# 50%         0.000000      1.000000      0.000000      0.000000       0.000000
# 75%         0.000000     11.000000      0.000000     10.000000       0.000000
# max         1.000000    431.000000    267.000000    366.000000      88.000000
#
#        LateAircraftDelay
# count       19629.000000
# mean           29.343675
# std            39.753529
# min             0.000000
# 25%             1.000000
# 50%            18.000000
# 75%            37.000000
# max           434.000000

# %%
def add_dummies(ds, dummy_cols, exp_cols):
    dummies = {}
    for col_name in dummy_cols:
        dummies = pd.get_dummies(ds[col_name], prefix = col_name)
        dummies = dummies.drop(dummies.columns[0], axis=1)
        ds = ds.join(dummies)
        exp_cols.extend(dummies.columns.tolist())
    return exp_cols, ds

# %%
df_flights = df_flights[(df_flights['Cancelled']==0) & (df_flights['Diverted']==0)].dropna(how='all')
df_flights['Delayed'] = df_flights.ArrDelay > 0
df_flights['DepHour'] = df_flights['CRSDepTime'].apply(lambda t: int(t / 100))

dummy_cols = ['Month', 'DayOfWeek', 'UniqueCarrier', 'Origin', 'Dest', 'DepHour']
exp_cols = ['Distance']
exp_cols, df_flights = add_dummies(df_flights, dummy_cols, exp_cols)
print exp_cols
# Out:
# ['Distance', 'DayOfWeek_2', 'DayOfWeek_3', 'DayOfWeek_4', 'DayOfWeek_5', 'DayOfWeek_6', 'DayOfWeek_7', 'UniqueCarrier_XE', 'Origin_ALB', 'Origin_AMA', 'Origin_AUS', 'Origin_BDL', 'Origin_BFL', 'Origin_BHM', 'Origin_BNA', 'Origin_BOI', 'Origin_BTR', 'Origin_BUF', 'Origin_BUR', 'Origin_BWI', 'Origin_CHS', 'Origin_CLE', 'Origin_CLT', 'Origin_CMH', 'Origin_COS', 'Origin_CRP', 'Origin_CRW', 'Origin_DAL', 'Origin_DAY', 'Origin_DEN', 'Origin_DTW', 'Origin_ELP', 'Origin_EWR', 'Origin_FAT', 'Origin_FLL', 'Origin_GEG', 'Origin_HOU', 'Origin_HRL', 'Origin_IAD', 'Origin_IAH', 'Origin_IND', 'Origin_ISP', 'Origin_JAN', 'Origin_JAX', 'Origin_LAS', 'Origin_LAX', 'Origin_LBB', 'Origin_LCH', 'Origin_LFT', 'Origin_LGB', 'Origin_LIT', 'Origin_MAF', 'Origin_MCI', 'Origin_MCO', 'Origin_MDW', 'Origin_MHT', 'Origin_MKE', 'Origin_MRY', 'Origin_MSY', 'Origin_OAK', 'Origin_OKC', 'Origin_OMA', 'Origin_ONT', 'Origin_ORD', 'Origin_ORF', 'Origin_PBI', 'Origin_PDX', 'Origin_PHL', 'Origin_PHX', 'Origin_PIT', 'Origin_PVD', 'Origin_RDU', 'Origin_RNO', 'Origin_ROC', 'Origin_RSW', 'Origin_SAN', 'Origin_SAT', 'Origin_SDF', 'Origin_SEA', 'Origin_SFO', 'Origin_SJC', 'Origin_SLC', 'Origin_SMF', 'Origin_SNA', 'Origin_STL', 'Origin_SYR', 'Origin_TPA', 'Origin_TUL', 'Origin_TUS', 'Dest_ALB', 'Dest_AMA', 'Dest_ATL', 'Dest_AUS', 'Dest_BDL', 'Dest_BFL', 'Dest_BHM', 'Dest_BNA', 'Dest_BOI', 'Dest_BUF', 'Dest_BUR', 'Dest_BWI', 'Dest_CLE', 'Dest_CMH', 'Dest_COS', 'Dest_CRP', 'Dest_DAL', 'Dest_DCA', 'Dest_DEN', 'Dest_DTW', 'Dest_ELP', 'Dest_EUG', 'Dest_EWR', 'Dest_FAT', 'Dest_FLL', 'Dest_GEG', 'Dest_GSO', 'Dest_HOU', 'Dest_HRL', 'Dest_IAD', 'Dest_IAH', 'Dest_IND', 'Dest_ISP', 'Dest_JAN', 'Dest_JAX', 'Dest_LAS', 'Dest_LAX', 'Dest_LBB', 'Dest_LGB', 'Dest_LIT', 'Dest_MAF', 'Dest_MCI', 'Dest_MCO', 'Dest_MDW', 'Dest_MHT', 'Dest_MRY', 'Dest_MSY', 'Dest_MYR', 'Dest_OAK', 'Dest_OKC', 'Dest_OMA', 'Dest_ONT', 'Dest_ORF', 'Dest_PBI', 'Dest_PDX', 'Dest_PHL', 'Dest_PHX', 'Dest_PIT', 'Dest_PVD', 'Dest_RDU', 'Dest_RIC', 'Dest_RNO', 'Dest_ROC', 'Dest_RSW', 'Dest_SAN', 'Dest_SAT', 'Dest_SAV', 'Dest_SDF', 'Dest_SEA', 'Dest_SFO', 'Dest_SJC', 'Dest_SLC', 'Dest_SMF', 'Dest_SNA', 'Dest_STL', 'Dest_SYR', 'Dest_TPA', 'Dest_TUL', 'Dest_TUS', 'Dest_XNA', 'DepHour_7', 'DepHour_8', 'DepHour_9', 'DepHour_10', 'DepHour_11', 'DepHour_12', 'DepHour_13', 'DepHour_14', 'DepHour_15', 'DepHour_16', 'DepHour_17', 'DepHour_18', 'DepHour_19', 'DepHour_20', 'DepHour_21', 'DepHour_22']

# %%
sns.set_style("whitegrid")
sns.countplot(x="Delayed", data=df_flights)

# %%
sns.countplot(x="DayOfWeek", hue="Delayed", data=df_flights, order = range(1, 8))

# %%
sns.countplot(x="DepHour", hue="Delayed", data=df_flights, order = range(0, 25))

# %%
sns.countplot(x="Origin", hue="Delayed", data=df_flights)

# %%
sns.countplot(x="Dest", hue="Delayed", data=df_flights)

# %%
sns.boxplot(x="Delayed", y="Distance", data=df_flights)

# %%
sns.violinplot(x = "Delayed", y="Distance", hue="Delayed", data=df_flights, 
               split=True, scale="count")
# Out:
# /Users/DicksonK/anaconda/lib/python2.7/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
fig, ax = plt.subplots()
sns.kdeplot(df_flights[-df_flights.Delayed].Distance, label="False", ax=ax)
sns.kdeplot(df_flights[df_flights.Delayed].Distance, label="True", ax=ax)

# %%
sns.violinplot(x="DayOfWeek", y="Distance", hue="Delayed", data=df_flights, 
               split=True, scale="count", order=range(1,8))

# %%
sns.violinplot(x="DepHour", y="Distance", hue="Delayed", data=df_flights, 
               split=True, scale="count", order=range(1,25))

# %%
sns.lmplot(x="Distance", y="ArrDelay", hue="Delayed", data=df_flights)

# %%
no_rows = df_flights['Delayed'].count()
half_rows = int(no_rows / 2)
flights_X = df_flights[exp_cols]
flights_y = df_flights['Delayed']
flights_X_train = flights_X.loc[0: half_rows - 1]
flights_y_train = flights_y.loc[0: half_rows - 1]
flights_X_test = flights_X.loc[half_rows: no_rows - 1]
flights_y_test = flights_y.loc[half_rows: no_rows - 1]

# %%
from sklearn import linear_model

logm = linear_model.LogisticRegression()
logm.fit(flights_X_train.values, flights_y_train.values)
logm.score(flights_X_test.values, flights_y_test.values)
# Out:
# 0.60248154224774408
